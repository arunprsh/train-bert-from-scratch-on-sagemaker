# %%
import pandas as pd

# %%
# %%time

df = pd.read_csv('s3://sagemaker-us-east-1-119174016168/data/covid_articles_clf_data.csv',  encoding='utf-8', names=['title', 'content', 'category', 'article'])
# Out:
# CPU times: user 58.7 s, sys: 14.1 s, total: 1min 12s
# Wall time: 2min 11s

# %%
df.head()
# Out:
#                                                title  \
# 0  Looking into the truth about modern workplace ...
# 1                  Hexo refiles financial statements
# 2  Japan raid, Turkey arrests in widening Ghosn p...
# 3  Pope's bodyguards criticised over slapping inc...
# 4   Lebanon denies president welcomed fugitive Ghosn
#
#                                              content  category  \
# 0  Hi, what are you looking for?\nBy\nPublished\n...         2
# 1  New York reported a record 90,132 new Covid-19...         2
# 2  Hi, what are you looking for?\nBy\nPublished\n...         2
# 3  Hi, what are you looking for?\nBy\nPublished\n...         2
# 4  Hi, what are you looking for?\nBy\nPublished\n...         2
#
#                                              article
# 0  Looking into the truth about modern workplace ...
# 1  Hexo refiles financial statements\nNew York re...
# 2  Japan raid, Turkey arrests in widening Ghosn p...
# ...

# %%
i = 0
for title in df.title:
    print(title)
    print('-' * 100)
    i += 1
    if i > 100:
        break
# Out:
# Looking into the truth about modern workplace environments
# ----------------------------------------------------------------------------------------------------
# Hexo refiles financial statements
# ----------------------------------------------------------------------------------------------------
# Japan raid, Turkey arrests in widening Ghosn probe
# ----------------------------------------------------------------------------------------------------
# Pope's bodyguards criticised over slapping incident
# ----------------------------------------------------------------------------------------------------
# Lebanon denies president welcomed fugitive Ghosn
# ----------------------------------------------------------------------------------------------------
# Lebanese lawyers want Ghosn prosecuted over Israel trip
# ----------------------------------------------------------------------------------------------------
# ' I did it alone ', Ghosn says of Japan escape
# ...
